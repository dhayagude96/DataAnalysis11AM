# %% [markdown]
# # head() and tail()
#
# In pandas, the head() and tail() functions are used to view a specified number of rows from the beginning or the end of a DataFrame. These functions are particularly useful when you have a large dataset, and you want to get a quick overview of its structure or examine a small portion of the data.
#
#
# head():
# ---
#
# The head() function returns the first n rows of a DataFrame.
#
# Syntax: DataFrame.head(n=5)
#
# By default, it returns the first 5 rows, but you can specify the number of rows you want by passing the n parameter
#
#
# tail():
# ---
#
# The tail() function returns the last n rows of a DataFrame.
#
# Syntax: DataFrame.tail(n=5)
#
# By default, it returns the last 5 rows, but you can specify the number of rows you want by passing the n parameter.

# %%
import pandas as pd

url ="https://www.timeanddate.com/weather/india/pune/ext"

df = pd.read_html(url)

df = df[0]

df.head(2)
# Out:
#   Unnamed: 0_level_0         Conditions                              \
#                  Day Unnamed: 1_level_1 Temperature         Weather
# 0      गुरु 11 जनवरी                NaN  31 / 19 °C  Partly cloudy.
# 1     शुक्र 12 जनवरी                NaN  32 / 17 °C   Mostly sunny.
#
#      Comfort                                      Precipitation         \
#   Feels Like     Wind Unnamed: 6_level_1 Humidity        Chance Amount
# 0      31 °C  10 km/h                  ↑      45%            0%      -
# 1      31 °C  10 km/h                  ↑      39%            0%      -
#
#             Sun
#              UV Sunrise Sunset
# 0  5 (Moderate)   07.09  18.15
# 1  3 (Moderate)   07.09  18.15

# %% [markdown]
# # df.columns
#
# columns attribute is used to retrieve the column labels (column names) of a DataFrame. It returns an Index object containing the column names. This attribute is useful when you want to get a list of column names or perform operations based on the column names.

# %%
column_name = df.columns

print(column_name)
# Out:
# MultiIndex([('Unnamed: 0_level_0',                'Day'),
#             (        'Conditions', 'Unnamed: 1_level_1'),
#             (        'Conditions',        'Temperature'),
#             (        'Conditions',            'Weather'),
#             (           'Comfort',         'Feels Like'),
#             (           'Comfort',               'Wind'),
#             (           'Comfort', 'Unnamed: 6_level_1'),
#             (           'Comfort',           'Humidity'),
#             (     'Precipitation',             'Chance'),
#             (     'Precipitation',             'Amount'),
#             (               'Sun',                 'UV'),
#             (               'Sun',            'Sunrise'),
#             (               'Sun',             'Sunset')],
#            )

# %%
df.head(1)
# Out:
#   Unnamed: 0_level_0         Conditions                              \
#                  Day Unnamed: 1_level_1 Temperature         Weather
# 0      गुरु 11 जनवरी                NaN  31 / 19 °C  Partly cloudy.
#
#      Comfort                                      Precipitation         \
#   Feels Like     Wind Unnamed: 6_level_1 Humidity        Chance Amount
# 0      31 °C  10 km/h                  ↑      45%            0%      -
#
#             Sun
#              UV Sunrise Sunset
# 0  5 (Moderate)   07.09  18.15

# %%
#Change Column Names :

df.columns = ["Day","NotReQ","Temp","Weather","Feels Like","Wind","NotReQ","Humidity","chance","Amount","UV","Sunrise","Sunset"]

# %%
df.head(1)
# Out:
#              Day NotReQ        Temp         Weather Feels Like     Wind  \
# 0  गुरु 11 जनवरी    NaN  31 / 19 °C  Partly cloudy.      31 °C  10 km/h
#
#   NotReQ Humidity chance Amount            UV Sunrise Sunset
# 0      ↑      45%     0%      -  5 (Moderate)   07.09  18.15

# %%
#To Viwe Specific Column from Data Frame

df[['Sunrise','UV']]
# Out:
#                                               Sunrise  \
# 0                                               07.09
# 1                                               07.09
# 2                                               07.09
# 3                                               07.09
# 4                                               07.09
# 5                                               07.09
# 6                                               07.09
# 7                                               07.09
# 8                                               07.09
# 9                                               07.09
# 10                                              07.09
# 11                                              07.09
# 12                                              07.09
# 13                                              07.09
# 14                                              07.09
# 15  * Updated गुरुवार 11 जनवरी 2024 08:54:14 Pune ...
#
#                                                    UV
# 0                                        5 (Moderate)
# 1                                        3 (Moderate)
# 2                                        5 (Moderate)
# 3                                        5 (Moderate)
# 4                                        5 (Moderate)
# 5                                        3 (Moderate)
# 6                                        3 (Moderate)
# 7                                        3 (Moderate)
# 8                                        5 (Moderate)
# 9                                        5 (Moderate)
# 10                                       3 (Moderate)
# 11                                       3 (Moderate)
# 12                                       5 (Moderate)
# 13                                       5 (Moderate)
# 14                                       3 (Moderate)
# 15  * Updated गुरुवार 11 जनवरी 2024 08:54:14 Pune ...

# %% [markdown]
# # df.dropna()
#
# In pandas, the dropna() function is used to remove missing or NaN (Not a Number) values from a DataFrame. Missing values can be a common issue in datasets, and dropna() provides a convenient way to handle them.

# %%
#Row = axis = 0
#column = axis = 1

df = df.dropna(axis=1,inplace=False)#column drop

df.head(2)
# Out:
#               Day        Temp         Weather Feels Like     Wind NotReQ  \
# 0   गुरु 11 जनवरी  31 / 19 °C  Partly cloudy.      31 °C  10 km/h      ↑
# 1  शुक्र 12 जनवरी  32 / 17 °C   Mostly sunny.      31 °C  10 km/h      ↑
#
#   Humidity chance Amount            UV Sunrise Sunset
# 0      45%     0%      -  5 (Moderate)   07.09  18.15
# 1      39%     0%      -  3 (Moderate)   07.09  18.15

# %% [markdown]
# # df.drop()
#
# drop() function is used to remove specified rows or columns from a DataFrame
#
# Dropping Rows:
# ----
# To drop specific rows, you can use the index parameter. You can specify either a single index or a list of indices to remove.
#
# Dropping Columns:
# ---
# To drop specific columns, you can use the columns parameter.
#
# Inplace Parameter:
# ---
# By default, the drop() function returns a new DataFrame with the specified rows or columns removed. If you want to modify the original DataFrame in place, you can use the inplace=True parameter.

# %%
#Single Column at a Time

#df = df.drop("NotReQ",axis=1,inplace=False)

#Multiple column at a Time

df = df.drop(columns=["NotReQ","Amount"],axis=1,inplace=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 7
#       1 #Single Column at a Time
#       2
#       3 #df = df.drop("NotReQ",axis=1,inplace=False)
#       4
#       5 #Multiple column at a Time
# ----> 7 df = df.drop(columns=["NotReQ","Amount"],axis=1,inplace=False)
#       9 df.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['NotReQ', 'Amount'] not found in axis"

# %%
#To delete Row
df = df.drop(15,axis=0,inplace=False)

df
# Out:
#                Day        Temp            Weather Feels Like     Wind  \
# 0    गुरु 11 जनवरी  31 / 19 °C     Partly cloudy.      31 °C  10 km/h
# 1   शुक्र 12 जनवरी  32 / 17 °C      Mostly sunny.      31 °C  10 km/h
# 2     शनि 13 जनवरी  32 / 16 °C             Sunny.      31 °C   7 km/h
# 3     रवि 14 जनवरी  32 / 15 °C  Scattered clouds.      31 °C   5 km/h
# 4     सोम 15 जनवरी  32 / 15 °C      Mostly sunny.      30 °C  14 km/h
# 5    मंगल 16 जनवरी  32 / 14 °C     Partly cloudy.      30 °C  16 km/h
# 6     बुध 17 जनवरी  30 / 14 °C      Mostly sunny.      28 °C  19 km/h
# 7    गुरु 18 जनवरी  28 / 13 °C            Cloudy.      27 °C   6 km/h
# 8   शुक्र 19 जनवरी  27 / 14 °C    Morning clouds.      26 °C   8 km/h
# 9     शनि 20 जनवरी  29 / 15 °C  Scattered clouds.      27 °C  10 km/h
# 10    रवि 21 जनवरी  29 / 15 °C     Broken clouds.      28 °C   9 km/h
# 11    सोम 22 जनवरी  29 / 15 °C          Overcast.      28 °C  20 km/h
# 12   मंगल 23 जनवरी  29 / 15 °C  Scattered clouds.      28 °C  11 km/h
# 13    बुध 24 जनवरी  30 / 15 °C      Mostly sunny.      28 °C   9 km/h
# 14   गुरु 25 जनवरी  30 / 15 °C            Cloudy.      28 °C  11 km/h
#
#    Humidity chance            UV Sunrise Sunset
# 0       45%     0%  5 (Moderate)   07.09  18.15
# 1       39%     0%  3 (Moderate)   07.09  18.15
# 2       35%     0%  5 (Moderate)   07.09  18.16
# 3       32%     0%  5 (Moderate)   07.09  18.17
# 4       30%     0%  5 (Moderate)   07.09  18.17
# 5       20%     0%  3 (Moderate)   07.09  18.18
# 6       22%     0%  3 (Moderate)   07.09  18.19
# 7       27%     4%  3 (Moderate)   07.09  18.19
# 8       22%     3%  5 (Moderate)   07.09  18.20
# 9       19%     2%  5 (Moderate)   07.09  18.20
# 10      25%     4%  3 (Moderate)   07.09  18.21
# 11      39%     4%  3 (Moderate)   07.09  18.22
# 12      29%     5%  5 (Moderate)   07.09  18.22
# 13      19%     2%  5 (Moderate)   07.09  18.23
# 14      19%     3%  3 (Moderate)   07.09  18.23

# %% [markdown]
# # df.replace()
#
#
# In pandas, the replace() function is used to replace values in a DataFrame. This function allows you to replace specified values with new values, providing flexibility in data cleaning and transformation.

# %%
#Single Data at a Time

df['UV'] = df['UV'].str.replace("(Moderate)"," ")

df.head()
# Out:
#               Day        Temp            Weather Feels Like     Wind Humidity  \
# 0   गुरु 11 जनवरी  31 / 19 °C     Partly cloudy.      31 °C  10 km/h      45%
# 1  शुक्र 12 जनवरी  32 / 17 °C      Mostly sunny.      31 °C  10 km/h      39%
# 2    शनि 13 जनवरी  32 / 16 °C             Sunny.      31 °C   7 km/h      35%
# 3    रवि 14 जनवरी  32 / 15 °C  Scattered clouds.      31 °C   5 km/h      32%
# 4    सोम 15 जनवरी  32 / 15 °C      Mostly sunny.      30 °C  14 km/h      30%
#
#   chance   UV Sunrise Sunset
# 0     0%  5     07.09  18.15
# 1     0%  3     07.09  18.15
# 2     0%  5     07.09  18.16
# 3     0%  5     07.09  18.17
# 4     0%  5     07.09  18.17

# %%
#Multiple data at Time

df['Day'] = df['Day'].replace({
    "गुरु":"Thus",
    "शुक्र":"Fri",
    "शनि":"Sat",
    "रवि":"Sun",
    "सोम":"Mon",
    "मंगल":"Tue",
    "बुध":"Wed",
    "जनवरी":"Jan"
    
},regex=True)

df
# Out:
#             Day        Temp            Weather Feels Like     Wind Humidity  \
# 0   Thus 11 Jan  31 / 19 °C     Partly cloudy.      31 °C  10 km/h      45%
# 1    Fri 12 Jan  32 / 17 °C      Mostly sunny.      31 °C  10 km/h      39%
# 2    Sat 13 Jan  32 / 16 °C             Sunny.      31 °C   7 km/h      35%
# 3    Sun 14 Jan  32 / 15 °C  Scattered clouds.      31 °C   5 km/h      32%
# 4    Mon 15 Jan  32 / 15 °C      Mostly sunny.      30 °C  14 km/h      30%
# 5    Tue 16 Jan  32 / 14 °C     Partly cloudy.      30 °C  16 km/h      20%
# 6    Wed 17 Jan  30 / 14 °C      Mostly sunny.      28 °C  19 km/h      22%
# 7   Thus 18 Jan  28 / 13 °C            Cloudy.      27 °C   6 km/h      27%
# 8    Fri 19 Jan  27 / 14 °C    Morning clouds.      26 °C   8 km/h      22%
# 9    Sat 20 Jan  29 / 15 °C  Scattered clouds.      27 °C  10 km/h      19%
# 10   Sun 21 Jan  29 / 15 °C     Broken clouds.      28 °C   9 km/h      25%
# 11   Mon 22 Jan  29 / 15 °C          Overcast.      28 °C  20 km/h      39%
# 12   Tue 23 Jan  29 / 15 °C  Scattered clouds.      28 °C  11 km/h      29%
# 13   Wed 24 Jan  30 / 15 °C      Mostly sunny.      28 °C   9 km/h      19%
# 14  Thus 25 Jan  30 / 15 °C            Cloudy.      28 °C  11 km/h      19%
#
#    chance   UV Sunrise Sunset
# 0      0%  5     07.09  18.15
# 1      0%  3     07.09  18.15
# 2      0%  5     07.09  18.16
# 3      0%  5     07.09  18.17
# 4      0%  5     07.09  18.17
# 5      0%  3     07.09  18.18
# 6      0%  3     07.09  18.19
# 7      4%  3     07.09  18.19
# 8      3%  5     07.09  18.20
# 9      2%  5     07.09  18.20
# 10     4%  3     07.09  18.21
# 11     4%  3     07.09  18.22
# 12     5%  5     07.09  18.22
# 13     2%  5     07.09  18.23
# 14     3%  3     07.09  18.23

# %% [markdown]
# # df.fillna()
#
# In pandas, the fillna() method is used to fill missing (NaN) values in a DataFrame or Series with specified values. It provides a convenient way to handle missing data by either replacing NaN values with a constant, using forward or backward fill methods

# %%
df1 = pd.read_excel("C:/Users/Vishal/Desktop/WatchData.xlsx")

df1
# Out:
#         Date     Brand  Units_Sold  Revenue (in lakhs)
# 0 2023-01-01     Titan       100.0               150.0
# 1 2023-01-02  Fastrack       120.0               180.0
# 2 2023-01-03     Casio         NaN                 NaN
# 3 2023-01-04    Fossil        80.0               120.0
# 4 2023-01-05     Titan         NaN                 NaN
# 5 2023-01-06     Casio        90.0               135.0
# 6 2023-01-07  Fastrack       110.0               165.0
# 7 2023-01-08    Fossil         NaN                 NaN
# 8 2023-01-09     Titan        95.0               142.5
# 9 2023-01-10     Casio       100.0               150.0

# %%
constantValue = df1.fillna(0)
constantValue
# Out:
#         Date     Brand  Units_Sold  Revenue (in lakhs)
# 0 2023-01-01     Titan       100.0               150.0
# 1 2023-01-02  Fastrack       120.0               180.0
# 2 2023-01-03     Casio         0.0                 0.0
# 3 2023-01-04    Fossil        80.0               120.0
# 4 2023-01-05     Titan         0.0                 0.0
# 5 2023-01-06     Casio        90.0               135.0
# 6 2023-01-07  Fastrack       110.0               165.0
# 7 2023-01-08    Fossil         0.0                 0.0
# 8 2023-01-09     Titan        95.0               142.5
# 9 2023-01-10     Casio       100.0               150.0

# %%
backfill = df1.fillna(method="bfill")

backfill
# Out:
#         Date     Brand  Units_Sold  Revenue (in lakhs)
# 0 2023-01-01     Titan       100.0               150.0
# 1 2023-01-02  Fastrack       120.0               180.0
# 2 2023-01-03     Casio        80.0               120.0
# 3 2023-01-04    Fossil        80.0               120.0
# 4 2023-01-05     Titan        90.0               135.0
# 5 2023-01-06     Casio        90.0               135.0
# 6 2023-01-07  Fastrack       110.0               165.0
# 7 2023-01-08    Fossil        95.0               142.5
# 8 2023-01-09     Titan        95.0               142.5
# 9 2023-01-10     Casio       100.0               150.0

# %%
forwardfill = df1.fillna(method="ffill")

forwardfill
# Out:
#         Date     Brand  Units_Sold  Revenue (in lakhs)
# 0 2023-01-01     Titan       100.0               150.0
# 1 2023-01-02  Fastrack       120.0               180.0
# 2 2023-01-03     Casio       120.0               180.0
# 3 2023-01-04    Fossil        80.0               120.0
# 4 2023-01-05     Titan        80.0               120.0
# 5 2023-01-06     Casio        90.0               135.0
# 6 2023-01-07  Fastrack       110.0               165.0
# 7 2023-01-08    Fossil       110.0               165.0
# 8 2023-01-09     Titan        95.0               142.5
# 9 2023-01-10     Casio       100.0               150.0
