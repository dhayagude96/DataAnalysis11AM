# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Custom Function

# %%
df = pd.read_csv("D:/Workshop/IPL_Data.csv")

df.head(2)
# Out:
#                Name  Team          Type  ValueinCR                 Full Name  \
# 0    Mayank Agarwal  PBKS      Batsman        12.0     Mayank Anurag Agarwal
# 1  Liam Livingstone  PBKS  All-Rounder        11.5  Liam Stephen Livingstone
#
#                                            Born                          Age  \
# 0        February 16, 1991 Bangalore, Karnataka  31 Years, 0 Months, 28 Days
# 1  August 4, 1993 Barrow-in-Furness, Cumberland  28 Years, 7 Months, 11 Days
#
#   National Side Batting Style    Bowling  ... Maidens  RunsConceded  Wickets  \
# 0         India  Right Handed  Off break  ...     NaN           NaN      NaN
# 1       England  Right Handed  Leg break  ...     0.0          13.0      0.0
#
#         Best   3s   5s  BowlingAVG  EconomyRate  S/R  Mtc
# 0        NaN  NaN  NaN         NaN          NaN  NaN  NaN
# 1  0/13 v MI  0.0  0.0         NaN         13.0  NaN  1.0
#
# [2 rows x 38 columns]

# %%
#Number of batsman in Punjab

print(df['Team'].unique())
print(df['Type'].unique())
# Out:
# ['PBKS' 'SRH' 'RR' 'RCB' 'MI' 'CSK' 'KKR' 'DC' 'LSG' 'GT']
# ['Batsman ' 'All-Rounder ' 'Bowler ' 'Wicket-Keeper ' 'Wicket-keeper ']

# %%
batsman = df[(df['Team']=='PBKS') & (df['Type']=='Batsman ')]

batsman.shape[0]
# Out:
# 3

# %%
def player_type(team,p_type):
    
    players =df[(df['Team']==team) & (df['Type']==p_type)]
    
    return players

# %%
player_type("CSK","All-Rounder ").shape[0]
# Out:
# 9

# %%
value_player = df[(df['ValueinCR']>12)&(df['Team']=="RCB")]

value_player
# Out:
#            Name Team      Type  ValueinCR    Full Name  \
# 72  Virat Kohli  RCB  Batsman        15.0  Virat Kohli
#
#                       Born                          Age National Side  \
# 72  November 5, 1988 Delhi  33 Years, 4 Months, 10 Days         India
#
#    Batting Style           Bowling  ... Maidens  RunsConceded  Wickets  \
# 72  Right Handed  Right-arm medium  ...     0.0         368.0      4.0
#
#           Best   3s   5s  BowlingAVG  EconomyRate    S/R   Mtc
# 72  2/25 v DCH  0.0  0.0        92.0         8.79  62.75  26.0
#
# [1 rows x 38 columns]

# %%
def value_player(cr,team):
    player=df[(df['ValueinCR']>cr)&(df['Team']==team)]
    return player

# %%
value_player(5,"SRH")
# Out:
#                  Name Team            Type  ValueinCR               Full Name  \
# 25    Kane Williamson  SRH        Batsman       14.00  Kane Stuart Williamson
# 26    Nicholas Pooran  SRH  Wicket-Keeper       10.75         Nicholas Pooran
# 27  Washington Sundar  SRH    All-Rounder        8.75       Washington Sundar
# 28     Rahul Tripathi  SRH        Batsman        8.50     Rahul Ajay Tripathi
# 29   Romario Shepherd  SRH    All-Rounder        7.75        Romario Shepherd
# 30    Abhishek Sharma  SRH    All-Rounder        6.50         Abhishek Sharma
#
#                                    Born                          Age  \
# 25              August 8, 1990 Tauranga   31 Years, 7 Months, 7 Days
# 26             October 2, 1995 Trinidad  26 Years, 5 Months, 14 Days
# 27  October 5, 1999 Chennai, Tamil Nadu  22 Years, 5 Months, 11 Days
# 28      March 2, 1991 Ranchi, Jharkhand  31 Years, 0 Months, 14 Days
# 29             November 26, 1994 Guyana  27 Years, 3 Months, 19 Days
# ...

# %%
df1 = pd.read_excel("D:/Workshop/CarSales.xlsx")

df1.head(1)
# Out:
#   InvoiceDate         Make     CountryName  IsDealer  SalePrice  CostPrice  \
# 0  2012-10-04  Rolls Royce  United Kingdom       NaN      95000      50000
#
#    TotalDiscount  DeliveryCharge  SpareParts  LaborCost  ...     Model Color  \
# 0          500.0             750         500        750  ...  Camargue   Red
#
#   ReportingYear  ReportingMonth  Registration_Date VehicleType  \
# 0          2012              10         1985-01-08      Saloon
#
#                           InvoiceNumber CountryISOCode OuterPostode  \
# 0  8B3D7F83-F42C-4523-A737-CDCBF7705B77            GBR           ST
#
#           Region
# 0  East Midlands
#
# [1 rows x 21 columns]

# %%
#Scatter Plot

sns.scatterplot(x=df1['CostPrice'],y=df1['SalePrice'],data=df1,hue=df1['CountryName'])
# Out:
# <Axes: xlabel='CostPrice', ylabel='SalePrice'>

# %%
sns.scatterplot(x=df1['CostPrice'],y=df1['SalePrice'],data=df1,hue=df1['Make'])
# Out:
# <Axes: xlabel='CostPrice', ylabel='SalePrice'>

# %%
sns.scatterplot(x=df1['TotalDiscount'],y=df1['SalePrice'],data=df1,hue=df1['CountryName'])
# Out:
# <Axes: xlabel='TotalDiscount', ylabel='SalePrice'>

# %%
sns.lineplot(x=df1['ReportingYear'],y=df1['CostPrice'],data=df1,hue=df1['CountryName'])
# Out:
# <Axes: xlabel='ReportingYear', ylabel='CostPrice'>

# %%
sns.barplot(x=df1['Model'],y=df1['SalePrice'],data=df1)
# Out:
# <Axes: xlabel='Model', ylabel='SalePrice'>
